# %%
import pandas as pd

# %%
source1=pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
source1.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
source1.drop(3)
#by default axis=0 i.e it delete data row by row(Horizontally)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 4              5         0       3
# 5              6         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
source1.drop('PassengerId',axis=1)
# to delete data vertically we change axis =1
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
source1
#all changes are temporary
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# To methods are there to change parmanent
# 1. reassignment
#     1. source1=source1.drop('PassengerId',axis=1)
# 2. bydefault inplace is false so cange it by true
#     1. source1.drop('PassengerId',axis=1,inplace=True)

# %%
source1.drop('PassengerId',axis=1,inplace=True)

# %%
source1
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
source1.dropna()
#remove all rows having nan value
# Out:
#      Survived  Pclass                                               Name  \
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 6           0       1                            McCarthy, Mr. Timothy J
# 10          1       3                    Sandstrom, Miss. Marguerite Rut
# 11          1       1                           Bonnell, Miss. Elizabeth
# ..        ...     ...                                                ...
# 871         1       1   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# 872         0       1                           Carlsson, Mr. Frans Olof
# 879         1       1      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# 887         1       1                       Graham, Miss. Margaret Edith
# 889         1       1                              Behr, Mr. Karl Howell
#
#         Sex   Age  SibSp  Parch    Ticket     Fare        Cabin Embarked
# ...

# %%
source1.dropna(axis=1)
#remove all columns having nan value
# Out:
#      Survived  Pclass                                               Name  \
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 6           0       1                            McCarthy, Mr. Timothy J
# 10          1       3                    Sandstrom, Miss. Marguerite Rut
# 11          1       1                           Bonnell, Miss. Elizabeth
# ..        ...     ...                                                ...
# 871         1       1   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# 872         0       1                           Carlsson, Mr. Frans Olof
# 879         1       1      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# 887         1       1                       Graham, Miss. Margaret Edith
# 889         1       1                              Behr, Mr. Karl Howell
#
#         Sex   Age  SibSp  Parch    Ticket     Fare        Cabin Embarked
# ...

# %%
# change parmantely
source1.dropna(inplace =True)

# %%
source1
# Out:
#      Survived  Pclass                                               Name  \
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 6           0       1                            McCarthy, Mr. Timothy J
# 10          1       3                    Sandstrom, Miss. Marguerite Rut
# 11          1       1                           Bonnell, Miss. Elizabeth
# ..        ...     ...                                                ...
# 871         1       1   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# 872         0       1                           Carlsson, Mr. Frans Olof
# 879         1       1      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# 887         1       1                       Graham, Miss. Margaret Edith
# 889         1       1                              Behr, Mr. Karl Howell
#
#         Sex   Age  SibSp  Parch    Ticket     Fare        Cabin Embarked
# ...

# %%
source1.set_index('Name',inplace=True)
#change index

# %%
source1
# Out:
#                                                     index  Survived  Pclass  \
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...      0         1       1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)            1         1       1
# McCarthy, Mr. Timothy J                                 2         0       1
# Sandstrom, Miss. Marguerite Rut                         3         1       3
# Bonnell, Miss. Elizabeth                                4         1       1
# ...                                                   ...       ...     ...
# Beckwith, Mrs. Richard Leonard (Sallie Monypeny)      178         1       1
# Carlsson, Mr. Frans Olof                              179         0       1
# Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)         180         1       1
# Graham, Miss. Margaret Edith                          181         1       1
# Behr, Mr. Karl Howell                                 182         1       1
#
# ...

# %%
source1.reset_index(inplace=True)
# again reset index by whole number

# %%
source2=pd.read_csv("taxonomy.csv")

# %%
source2.fillna("blank")
# fill nan to blank
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency     blank                 blank
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]
